# %%
---
layout: post
assignment: true
courses: { csse: {week: 16} }
toc: false
tailwind: true
infoGraph: game-engine-essentials-summative
title: GameEngine Essentials Summative Assessment 
description: "A summative assessment of the OCS GameEngine, capturing GameEngine Essentials, Game Creativity, and Problem-Solving Skills."
author: John Mortensen
permalink: /game/essentials/summative
---

# %% [markdown]
# <!-- Infographic - this depends on page.infoGraph frontmatter being set -->
# {%- include tailwind/infograph.html -%}

# %% [markdown]
# ## Summative Hacks
#
# Reflect on Learning Objectives
# - Understand the basics of object-oriented programming and game mechanics.
#   - Top experieces in this category
#
# - Collaborate effectively within a development team.
#   - Discuss Kanban Board and Retrospective Thinking
#
# - Apply agile and scrum practices to manage your project.
#   - Discuss how you managed iterations, tests, and checkpoints
#
# - Design, develop, and extend game levels using the OCS GameEngine.
#   - Create thre 1-minute demos on game
#
# - Reflect on your progress through formative and summative reviews.
#   - rose, bud, thorn reflections
#
# - Analytics from OCS
#   - Commit, Integrate, Test: use OCS metrics
