# %% [raw]
# ---
# layout: post
# tailwind: true
# title: Sprint 4 - CSSE Objectives
# description: Exploring the Game Engine
# courses: { csse: {week: 13} }
# permalink: /csse/sprint4/objectives
#
# Games:
#   - title: "GameEngine V1 Collection"
#     image: "gamify/lessons/adventure.png"
#     alt: "GameEngine V1 Collection"
#     link: "/gamify/adventureGame"
#     lessonLink: "/game/guide"
#     category: "Adventure"
#     difficulty: "Beginner"
#     description: "This page contains example games and levels."
#     author: "Student Community"
#     keyPoints:
#       - "Background, Players, and NPCs"
#       - "Interact function"
#       - "Reaction function"
#       - "Game-in-Game"
#
#   - title: "Fortune Finders Gamification"
#     image: "gamify/lessons/fortune.png"
#     alt: "Fortune Finders"
#     link: "/gamify/fortuneFinders"
#     lessonLink: "/game/guide"
#     category: "Finance"
#     difficulty: "Intermediate"
#     description: "This page contains games developed for finance simulations."
#     author: "Student Community"
#     keyPoints:
#       - "Interactive NPC conversations"
#       - "CS knowledge questions"
#       - "Virtual currency system"
#       - "Multiple game modes"
#       - "Crypto trading simulation"
#
#   - title: "Platformer Game Engine"
#     image: "gamify/lessons/platformer.png"
#     alt: "Mario-style Platformer"
#     link: "/navigation/game"
#     lessonLink: "/game/guide/"
#     category: "Action"
#     difficulty: "Advanced"
#     description: "Using an GameEngine V1 predecessor, students will learn game development concepts through a classic Mario-style platformer game."
#     author: "Student Community"
#     keyPoints:
#       - "Game physics simulation"
#       - "Collision detection algorithms"
#       - "Sprite animation techniques"
#       - "Level design principles"
#       - "Team collaboration tools"
#
#   - title: "Mansion Game"
#     image: "gamify/lessons/mansionGame.png"
#     alt: "Mansion Game"
#     link: "/gamify/mansionGame"
#     lessonLink: "/game/guide/"
#     category: "Adventure"
#     difficulty: "Beginner"
#     description: "A text-based adventure game set in a mysterious mansion, where players solve puzzles and uncover secrets."
#     author: "Student Community"
#     keyPoints:
#       - "Text-based adventure mechanics"
#       - "Puzzle design"
#       - "Storytelling and narrative"
#       - "Player decision-making"
#
#   - title: "Murder Mystery Game"
#     image: "gamify/lessons/murderMystery.png"
#     alt: "Murder Mystery Game"
#     link: "/gamify/murderMystery"
#     lessonLink: "/game/guide/"
#     category: "Adventure"
#     difficulty: "Intermediate"
#     description: "A murder mystery game where players gather clues, interrogate suspects, and solve the crime."
#     author: "Student Community"
#     keyPoints:
#       - "Investigation mechanics"
#       - "Clue collection"
#       - "Interrogation techniques"
#       - "Deduction and reasoning"
#
# ---

# %% [markdown]
# <div class="bg-gray-800 rounded-xl p-8 mb-12 transform hover:scale-105">
#   <h2 class="text-4xl font-bold justify-center mb-4">Ready to Level Up Your Coding Skills?</h2>
#   <p class="mb-6 text-center">
#     Welcome to your next coding adventure! Before you begin, review the required development tools and background knowledge. Use the links provided to ensure you’re set up for success.
#   </p>
#   <div class="flex flex-wrap justify-center gap-4">
#     <a href="{{ site.baseurl }}/tools/" class="rounded-xl px-6 py-3 hover:opacity-90 transform hover:scale-105">
#       🛠️ Required Development Tools
#     </a>
#     <a href="{{ site.baseurl }}/javascript/variables/dom/csse/" class="rounded-xl px-6 py-3 hover:opacity-90 transform hover:scale-105">
#       📚 Required JavaScript Background
#     </a>
#   </div>
# </div>

# %% [markdown]
# <div class="bg-gray-800 rounded-xl p-8 mb-12">
#     <!-- Objectives Header -->
#     <div class="text-center mb-3">
#         <h3 class="font-bold">Learning Objectives</h3>
#     </div>
#     <ul class="list-disc list-inside text-left mx-auto max-w-2xl mb-4">
#         <li>Understand the basics of object-oriented programming and game mechanics.</li>
#         <li>Collaborate effectively within a development team.</li>
#         <li>Apply agile and scrum practices to manage your project.</li>
#         <li>Design, develop, and extend game levels using the OCS GameEngine.</li>
#         <li>Reflect on your progress through formative and summative reviews.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="container">
#   <!-- Team and Objectives Grid -->
#   <div class="grid grid-cols-1 md:grid-cols-2 gap-6 mb-4">
#     <!-- Team Setup Card -->
#     <div class="bg-gray-800 rounded-xl p-4">
#       <h3 class="font-bold">Team Dynamics</h3>
#       <div class="rounded-lg p-3">
#         <strong>Collaboration Goals:</strong> In teams of 3–4, you’ll work on a GitHub collaborative game project
#       </div>
#     </div>
#        <!-- Story Development Card -->
#     <div class="bg-gray-800 rounded-xl p-4">
#       <h3 class="font-bold">Establish Your Story</h3>
#       <div class="rounded-lg p-3">
#         <strong>Creative Goals:</strong> Build the narrative and game conclusion as a Agile/Scrum team
#       </div>
#     </div>
#     <!-- Game Levels Card -->
#     <div class="bg-gray-800 rounded-xl p-4">
#       <h3 class="font-bold">Technical Challenges</h3>
#       <div class="rounded-lg p-3">
#         <strong>Coding Goals:</strong> Learn OOP by improving game mechanics and levels as you work in small coding groups
#       </div>
#     </div>
#     <!-- Assessment Card -->
#     <div class="bg-gray-800 rounded-xl p-4">
#       <h3 class="font-bold">Sharing Accomplishments</h3>
#       <div class="rounded-lg p-3">
#         <strong>Assessment Goals:</strong> Permform weekly formative and end of sprint summative reviews on game play and code
#       </div>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div class="bg-gray-800 rounded-xl p-8 mb-12">
#     <!-- Sprint Header -->
#     <div class="text-center mb-3">
#         <h3 class="font-bold">Sprint Guide</h3>
#     </div>
#     <ul class="list-disc list-inside text-left mx-auto max-w-2xl mb-4">
#         <li><strong>Form Your Team: </strong>Teams will be created using personas to ensure diverse skills and perspectives.</li>
#         <li><strong>Pick a Game: </strong>Choose from the game options below to serve as your project foundation.</li>
#         <li><strong>Ideate on Game's Purpose: </strong>Carefully read through the sprint requirements, create your own ideas, and define your game's purpose.</li>
#         <li><strong>Create Issues and Kanban: </strong>Using Game's Purpose and Ideation create team and small group issues to capture requirements and assigning tasks.</li>
#         <li><strong>Plan Your UI and Assets: </strong>Use GameBuilder to design your user interface, assets, and initial levels of the game.</li>
#         <li><strong>Start Coding: </strong>Begin working in pairs or small groups to add or extend game levels. Create and attend tech talks for guidance and inspiration.</li>
#         <li><strong>Prepare for Reviews: </strong>Start iterative process by preparing for live reviews, including weekly formative checkpoints and a final summative sprint retrospective.</li>
#         <li><strong>Commit, Integrate, Test: </strong>Commit daily, integrate before each live review, and test prior to each live review.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="container mx-auto px-4 py-8">
#
#   <!-- Game Cards Grid - Responsive: 1 on mobile, 2 on tablet, 3-4 on desktop -->
#   <div class="grid grid-cols-1 md:grid-cols-2 lg:grid-cols-2 xl:grid-cols-3 gap-6 mb-12">
#     {% for game in page.Games %}
#       <div class="bg-gray-800 rounded-xl shadow-lg hover:shadow-2xl transition-all duration-300 overflow-hidden group transform hover:-translate-y-2">
#         <!-- Game Image Container -->
#         <div class="relative h-48 overflow-hidden bg-gradient-to-br from-gray-700 to-gray-900">
#           <!-- Make the entire image area clickable -->
#           <a href="{{ site.baseurl }}{{ game.link }}" class="block w-full h-full">
#             <img src="{{ site.baseurl }}/images/{{ game.image }}"
#                  alt="{{ game.alt }}"
#                  class="w-full h-full object-cover transition-all duration-300 group-hover:scale-110">
#           </a>
#           <!-- Category Badge -->
#           {% if game.category %}
#           <div class="absolute top-3 left-3 bg-black bg-opacity-80 text-white px-2 py-1 rounded-full text-xs font-semibold pointer-events-none">
#             {{ game.category }}
#           </div>
#           {% endif %}
#           <!-- Difficulty Badge -->
#           {% if game.difficulty %}
#           <div class="absolute top-3 right-3 bg-blue-600 bg-opacity-90 text-white px-2 py-1 rounded-full text-xs font-semibold pointer-events-none">
#             {{ game.difficulty }}
#           </div>
#           {% endif %}
#           <!-- Play Overlay - Now clickable -->
#           <div class="absolute inset-0 bg-opacity-50 opacity-0 group-hover:opacity-100 transition-opacity duration-300 flex items-center justify-center pointer-events-none">
#             <div class="bg-opacity-90 bg-black rounded-full p-4 flex items-center justify-center">
#               <span class="text-4xl leading-none">▶</span>
#             </div>
#           </div>
#         </div>
#         <!-- Game Info -->
#         <div class="p-6">
#           <!-- Title and Author -->
#           <div class="mb-3">
#             <h3 class="text-xl font-bold mb-1">{{ game.title }}</h3>
#             {% if game.author %}
#             <p class="text-sm">{{ game.author }}</p>
#             {% endif %}
#           </div>
#           <!-- Description -->
#           {% if game.description %}
#           <p class="text-sm mb-4 line-clamp-3">{{ game.description }}</p>
#           {% endif %}
#           <!-- Key Learning Points -->
#           {% if game.keyPoints %}
#           <div class="mb-4">
#             <h4 class="text-sm font-semibold text-gray-200 mb-2">What You'll Learn:</h4>
#             <div class="flex flex-wrap gap-1">
#               {% for point in game.keyPoints limit:3 %}
#                 <span class="bg-gradient-to-r from-green-400 to-green-300 text-white text-xs px-2 py-1 rounded-full">{{ point }}</span>
#               {% endfor %}
#             </div>
#           </div>
#           {% endif %}
#           <!-- Dual Action Buttons -->
#           <div class="flex gap-2">
#             <!-- Play Game Button (uses link) -->
#             <a href="{{ site.baseurl }}{{ game.link }}"
#                class="flex-1 bg-gradient-to-r from-green-600 to-green-500 text-white text-center py-3 rounded-lg font-semibold hover:from-green-500 hover:to-green-400 transition-all duration-300 transform hover:scale-105">
#               🎮 Play Game
#             </a>
#             <!-- Start Learning Button (uses lessonLink) -->
#             {% if game.lessonLink %}
#             <a href="{{ site.baseurl }}{{ game.lessonLink }}"
#                class="flex-1 bg-gradient-to-r from-blue-400 to-purple-400 text-white text-center py-3 rounded-lg font-semibold hover:from-blue-400 hover:to-purple-400 transition-all duration-300 transform hover:scale-105">
#               📚 Learn More
#             </a>
#             {% endif %}
#           </div>
#         </div>
#       </div>
#     {% endfor %}
#   </div>
#
# </div>
#
# <style>
#   .line-clamp-3 {
#     display: -webkit-box;
#     -webkit-line-clamp: 3;
#     -webkit-box-orient: vertical;
#     overflow: hidden;
#   }
# </style>
