// %% [raw]
// ---
// layout: post
// courses: { csa: {week: 19} }
// toc: true
// codemirror: true
// title: 2021 FRQ 3
// year: 2021
// frq_number: 3
// unit: Unit 4
// category: Arrays and ArrayList Manipulation
// description: "AP CSA 2021 FRQ #3 - Unit 4 - Arrays"
// permalink: /csa/frqs/2021/3
// author: Samhita
// ---

// %% [markdown]
// ## FRQ Question
//
// A high school club maintains information about its members in a MemberInfo object. A MemberInfo object stores a club member's name, year of graduation, and whether or not the club member is in good standing. A member who is in good standing has fulfilled all the responsibilities of club membership.
//
// A partial declaration of the MemberInfo class is shown below:
//
// ```java
// public class MemberInfo {
//     public MemberInfo(String name, int gradYear, boolean hasGoodStanding) { }
//     public int getGradYear() { }
//     public boolean inGoodStanding() { }
// }
// ```
//
// The ClubMembers class maintains a list of current club members:
//
// ```java
// public class ClubMembers {
//     private ArrayList<MemberInfo> memberList;
//     public void addMembers(String[] names, int gradYear) { }
//     public ArrayList<MemberInfo> removeMembers(int year) { }
// }
// ```

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto; margin-bottom: 20px;">
//     <div style="background: linear-gradient(135deg, #2c3e50 0%, #3498db 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #f1c40f;">
//         <h3 style="margin: 0; color: #f1c40f; font-weight: 600; font-size: 18px;">🍿 Popcorn Hack 1: Object Instantiation</h3>
//         <p style="margin: 8px 0 0 0; color: rgba(255,255,255,0.9); font-size: 14px;">Based on the MemberInfo constructor, how would you create a new member named "Alice" graduating in 2024 who is in good standing?</p>
//     </div>
//
//     <div style="background: #1a252f; padding: 25px; border-radius: 0 0 12px 12px;">
//         <div id="hack1-options" style="display: flex; flex-direction: column; gap: 10px;">
//             <button onclick="checkHack1(0)" class="h1-btn" style="text-align: left; background: #2c3e50; color: #ecf0f1; border: 2px solid #34495e; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 14px; transition: all 0.2s;">A) new MemberInfo("Alice", 2024)</button>
//             <button onclick="checkHack1(1)" class="h1-btn" style="text-align: left; background: #2c3e50; color: #ecf0f1; border: 2px solid #34495e; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 14px; transition: all 0.2s;">B) new MemberInfo("Alice", 2024, true)</button>
//             <button onclick="checkHack1(2)" class="h1-btn" style="text-align: left; background: #2c3e50; color: #ecf0f1; border: 2px solid #34495e; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 14px; transition: all 0.2s;">C) MemberInfo.create("Alice", 2024, true)</button>
//             <button onclick="checkHack1(3)" class="h1-btn" style="text-align: left; background: #2c3e50; color: #ecf0f1; border: 2px solid #34495e; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-family: 'Courier New', monospace; font-size: 14px; transition: all 0.2s;">D) new MemberInfo(true, 2024, "Alice")</button>
//         </div>
//
//         <div id="hack1-feedback" style="display: none; margin-top: 20px; padding: 15px; border-radius: 8px; font-size: 14px; line-height: 1.5;"></div>
//     </div>
// </div>
//
// <style>
// .h1-btn:hover { background: #34495e !important; border-color: #f1c40f !important; }
// </style>
//
// <script>
// function checkHack1(selected) {
//     const btns = document.querySelectorAll('.h1-btn');
//     const feedback = document.getElementById('hack1-feedback');
//
//     // Reset styles
//     btns.forEach(btn => {
//         btn.style.borderColor = '#34495e';
//         btn.style.background = '#2c3e50';
//     });
//
//     feedback.style.display = 'block';
//
//     if (selected === 1) {
//         btns[1].style.borderColor = '#2ecc71';
//         btns[1].style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.borderLeft = '4px solid #2ecc71';
//         feedback.style.color = '#ecf0f1';
//         feedback.innerHTML = '<strong style="color: #2ecc71;">✅ Correct!</strong> The constructor signature is <code>MemberInfo(String name, int gradYear, boolean hasGoodStanding)</code>. You must provide all three arguments in the exact order specified.';
//     } else {
//         btns[selected].style.borderColor = '#e74c3c';
//         btns[selected].style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.borderLeft = '4px solid #e74c3c';
//         feedback.style.color = '#ecf0f1';
//
//         if (selected === 0) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> The constructor requires three parameters, but only two were provided. You missed the boolean for good standing.';
//         if (selected === 2) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> To instantiate an object in Java, you must use the <code>new</code> keyword followed by the class name, not a static <code>create</code> method (unless one was explicitly defined, which it isn\'t here).';
//         if (selected === 3) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> The order of arguments matters! The constructor expects <code>(String, int, boolean)</code>, but this provides <code>(boolean, int, String)</code>.';
//     }
// }
// </script>

// %%
// CODE_RUNNER: Club Members ArrayList Management

import java.util.ArrayList;

class MemberInfo {
    private String name;
    private int gradYear;
    private boolean hasGoodStanding;
    
    public MemberInfo(String name, int gradYear, boolean hasGoodStanding) {
        this.name = name;
        this.gradYear = gradYear;
        this.hasGoodStanding = hasGoodStanding;
    }
    
    public int getGradYear() { return gradYear; }
    public boolean inGoodStanding() { return hasGoodStanding; }
    public String toString() { return name + " (" + gradYear + ") - " + (hasGoodStanding ? "Good" : "Bad"); }
}

class ClubMembers {
    private ArrayList<MemberInfo> memberList;
    
    public ClubMembers() {
        memberList = new ArrayList<>();
    }
    
    public void addMembers(String[] names, int gradYear) {
        // PART (a): Implement this method
        for (String name : names) {
            memberList.add(new MemberInfo(name, gradYear, true));
        }
    }
    
    public ArrayList<MemberInfo> removeMembers(int year) {
        // PART (b): Implement this method
        ArrayList<MemberInfo> graduated = new ArrayList<>();
        
        for (int i = memberList.size() - 1; i >= 0; i--) {
            MemberInfo member = memberList.get(i);
            if (member.getGradYear() <= year) {
                if (member.inGoodStanding()) {
                    graduated.add(member);
                }
                memberList.remove(i);
            }
        }
        
        return graduated;
    }
    
    public void printMembers() {
        System.out.println("Current Members:");
        for (MemberInfo m : memberList) {
            System.out.println("  " + m);
        }
    }
}

public class Main {
    public static void main(String[] args) {
        ClubMembers club = new ClubMembers();
        
        // Add members
        String[] names1 = {"FOX, STEVE", "XIN, MICHAEL"};
        club.addMembers(names1, 2018);
        
        String[] names2 = {"SMITH, JANE", "GARCIA, MARIA"};
        club.addMembers(names2, 2019);
        
        System.out.println("Before removeMembers(2018):");
        club.printMembers();
        
        ArrayList<MemberInfo> graduated = club.removeMembers(2018);
        
        System.out.println("\nAfter removeMembers(2018):");
        club.printMembers();
        
        System.out.println("\nGraduated in good standing:");
        for (MemberInfo m : graduated) {
            System.out.println("  " + m);
        }
    }
}

Main.main(null);

// %% [markdown]
// ## Part (a) - addMembers
//
// Write the ClubMembers method `addMembers`, which takes two parameters:
// - A String array containing the names of new club members to be added
// - The graduation year of all the new club members
//
// The method adds the new members to the `memberList` instance variable. The names can be added in any order. All members added are initially in good standing and share the same graduation year.
//
// ```java
// public void addMembers(String[] names, int gradYear)
// ```

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto; margin-bottom: 20px;">
//     <div style="background: linear-gradient(135deg, #8e44ad 0%, #9b59b6 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #2ecc71;">
//         <h3 style="margin: 0; color: #2ecc71; font-weight: 600; font-size: 18px;">🍿 Popcorn Hack 2: Array Iteration</h3>
//         <p style="margin: 8px 0 0 0; color: rgba(255,255,255,0.9); font-size: 14px;">In <code>addMembers</code>, you need to iterate through the <code>String[] names</code> array. Which loop is the most elegant and least prone to off-by-one errors for this task?</p>
//     </div>
//
//     <div style="background: #1a1a1a; padding: 25px; border-radius: 0 0 12px 12px;">
//         <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 15px;">
//             <div onclick="checkHack2(0)" class="h2-card" style="background: #2c2c2c; border: 2px solid #444; border-radius: 8px; padding: 15px; cursor: pointer; transition: all 0.2s;">
//                 <code style="color: #e0e0e0; font-size: 13px;">for (int i=0; i<=names.length; i++)</code>
//             </div>
//             <div onclick="checkHack2(1)" class="h2-card" style="background: #2c2c2c; border: 2px solid #444; border-radius: 8px; padding: 15px; cursor: pointer; transition: all 0.2s;">
//                 <code style="color: #e0e0e0; font-size: 13px;">for (String n : names)</code>
//             </div>
//             <div onclick="checkHack2(2)" class="h2-card" style="background: #2c2c2c; border: 2px solid #444; border-radius: 8px; padding: 15px; cursor: pointer; transition: all 0.2s;">
//                 <code style="color: #e0e0e0; font-size: 13px;">while (names.hasNext())</code>
//             </div>
//             <div onclick="checkHack2(3)" class="h2-card" style="background: #2c2c2c; border: 2px solid #444; border-radius: 8px; padding: 15px; cursor: pointer; transition: all 0.2s;">
//                 <code style="color: #e0e0e0; font-size: 13px;">for (int i=1; i<names.length; i++)</code>
//             </div>
//         </div>
//
//         <div id="hack2-feedback" style="display: none; margin-top: 20px; padding: 15px; border-radius: 8px; font-size: 14px; line-height: 1.5;"></div>
//     </div>
// </div>
//
// <style>
// .h2-card:hover { transform: translateY(-2px); border-color: #2ecc71 !important; box-shadow: 0 4px 8px rgba(0,0,0,0.2); }
// </style>
//
// <script>
// function checkHack2(selected) {
//     const cards = document.querySelectorAll('.h2-card');
//     const feedback = document.getElementById('hack2-feedback');
//
//     cards.forEach(card => {
//         card.style.borderColor = '#444';
//         card.style.background = '#2c2c2c';
//     });
//
//     feedback.style.display = 'block';
//
//     if (selected === 1) {
//         cards[1].style.borderColor = '#2ecc71';
//         cards[1].style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.borderLeft = '4px solid #2ecc71';
//         feedback.style.color = '#ecf0f1';
//         feedback.innerHTML = '<strong style="color: #2ecc71;">✅ Correct!</strong> The enhanced for-loop (for-each loop) is perfect here because we just need to read each name and don\'t need the index. It completely avoids <code>ArrayIndexOutOfBoundsException</code>.';
//     } else {
//         cards[selected].style.borderColor = '#e74c3c';
//         cards[selected].style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.borderLeft = '4px solid #e74c3c';
//         feedback.style.color = '#ecf0f1';
//
//         if (selected === 0) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> This loop will cause an <code>ArrayIndexOutOfBoundsException</code> because the condition is <code>i <= names.length</code>. Valid indices go up to <code>length - 1</code>.';
//         if (selected === 2) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> Arrays in Java do not have a <code>hasNext()</code> method. That method belongs to Iterators and Scanners.';
//         if (selected === 3) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> This loop starts at index 1, which means it will skip the very first element (index 0) of the array.';
//     }
// }
// </script>

// %% [markdown]
// ## Scoring Guidelines Part (a)
//
// | Criterion | Decision Rules | Points |
// |-----------|---|---|
// | Accesses all elements of names (no bounds errors) | Responses will not earn the point if they fail to access elements of the array, even if loop bounds are correct | 1 |
// | Instantiates a MemberInfo object with name from array, provided year, and good standing | | 1 |
// | Adds MemberInfo objects to memberList (in the context of a loop) | Responses can earn the point even if they instantiate MemberInfo objects incorrectly | 1 |
// | **Total for part (a)** | | **3** |

// %% [markdown]
// ## Part (b) - removeMembers
//
// Write the ClubMembers method `removeMembers`, which takes the following actions:
//
// 1. **Returns** a list of all students who have graduated and are in good standing
//    - A member has graduated if their graduation year is **less than or equal to** the method's year parameter
//    - If no members meet these criteria, an empty list is returned
//
// 2. **Removes** from memberList all members who have graduated, regardless of whether or not they are in good standing
//
// ### Example
//
// Given the following `memberList` before calling `removeMembers(2018)`:
//
// | Name | Year | Good Standing |
// |------|------|---|
// | SMITH, JANE | 2019 | false |
// | FOX, STEVE | 2018 | true |
// | XIN, MICHAEL | 2017 | false |
// | GARCIA, MARIA | 2020 | true |
//
// After `removeMembers(2018)`:
//
// **memberList:**
//
// | Name | Year | Good Standing |
// |------|------|---|
// | SMITH, JANE | 2019 | false |
// | GARCIA, MARIA | 2020 | true |
//
// **Returned ArrayList:**
//
// | Name | Year | Good Standing |
// |------|------|---|
// | FOX, STEVE | 2018 | true |
//
// ```java
// public ArrayList<MemberInfo> removeMembers(int year)
// ```

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto; margin-bottom: 20px;">
//     <div style="background: linear-gradient(135deg, #e67e22 0%, #d35400 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #fff;">
//         <h3 style="margin: 0; color: #fff; font-weight: 600; font-size: 18px;">🍿 Popcorn Hack 3: The ArrayList Removal Trap</h3>
//         <p style="margin: 8px 0 0 0; color: rgba(255,255,255,0.9); font-size: 14px;">When removing elements from an <code>ArrayList</code>, why is it dangerous to use a standard forward loop <code>for (int i = 0; i < list.size(); i++)</code>?</p>
//     </div>
//
//     <div style="background: #2c3e50; padding: 25px; border-radius: 0 0 12px 12px;">
//
//         <div style="background: #1a252f; border-radius: 8px; padding: 15px; margin-bottom: 20px;">
//             <p style="color: #bdc3c7; margin: 0 0 10px 0; font-size: 14px;">Consider this scenario: You are at index 1 and you remove the element.</p>
//             <div style="display: flex; gap: 5px; margin-bottom: 10px;">
//                 <div style="background: #34495e; color: #fff; padding: 5px 10px; border-radius: 4px; font-family: monospace;">[0] A</div>
//                 <div style="background: #e74c3c; color: #fff; padding: 5px 10px; border-radius: 4px; font-family: monospace;">[1] B (Remove)</div>
//                 <div style="background: #34495e; color: #fff; padding: 5px 10px; border-radius: 4px; font-family: monospace;">[2] C</div>
//                 <div style="background: #34495e; color: #fff; padding: 5px 10px; border-radius: 4px; font-family: monospace;">[3] D</div>
//             </div>
//         </div>
//
//         <div id="hack3-options" style="display: flex; flex-direction: column; gap: 10px;">
//             <button onclick="checkHack3(0)" class="h3-btn" style="text-align: left; background: #34495e; color: #ecf0f1; border: 2px solid #455a64; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-size: 14px; transition: all 0.2s;">A) It throws a ConcurrentModificationException.</button>
//             <button onclick="checkHack3(1)" class="h3-btn" style="text-align: left; background: #34495e; color: #ecf0f1; border: 2px solid #455a64; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-size: 14px; transition: all 0.2s;">B) The elements shift left, so the next element (C) moves to index 1. The loop increments to index 2, skipping C entirely.</button>
//             <button onclick="checkHack3(2)" class="h3-btn" style="text-align: left; background: #34495e; color: #ecf0f1; border: 2px solid #455a64; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-size: 14px; transition: all 0.2s;">C) The size of the ArrayList cannot change while inside a for loop.</button>
//             <button onclick="checkHack3(3)" class="h3-btn" style="text-align: left; background: #34495e; color: #ecf0f1; border: 2px solid #455a64; padding: 12px 15px; border-radius: 8px; cursor: pointer; font-size: 14px; transition: all 0.2s;">D) It leaves a null value at index 1, causing NullPointerExceptions later.</button>
//         </div>
//
//         <div id="hack3-feedback" style="display: none; margin-top: 20px; padding: 15px; border-radius: 8px; font-size: 14px; line-height: 1.5;"></div>
//     </div>
// </div>
//
// <style>
// .h3-btn:hover { background: #455a64 !important; border-color: #e67e22 !important; }
// </style>
//
// <script>
// function checkHack3(selected) {
//     const btns = document.querySelectorAll('.h3-btn');
//     const feedback = document.getElementById('hack3-feedback');
//
//     btns.forEach(btn => {
//         btn.style.borderColor = '#455a64';
//         btn.style.background = '#34495e';
//     });
//
//     feedback.style.display = 'block';
//
//     if (selected === 1) {
//         btns[1].style.borderColor = '#2ecc71';
//         btns[1].style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.background = 'rgba(46, 204, 113, 0.1)';
//         feedback.style.borderLeft = '4px solid #2ecc71';
//         feedback.style.color = '#ecf0f1';
//         feedback.innerHTML = '<strong style="color: #2ecc71;">✅ Correct!</strong> When you remove an element, all subsequent elements shift one position to the left. If your loop counter <code>i</code> increments, you will skip the element that just shifted into the current index. <strong>Solution:</strong> Iterate backwards <code>for (int i = list.size() - 1; i >= 0; i--)</code> or use an Iterator.';
//     } else {
//         btns[selected].style.borderColor = '#e74c3c';
//         btns[selected].style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.background = 'rgba(231, 76, 60, 0.1)';
//         feedback.style.borderLeft = '4px solid #e74c3c';
//         feedback.style.color = '#ecf0f1';
//
//         if (selected === 0) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> <code>ConcurrentModificationException</code> typically happens when using an enhanced for-loop (for-each) and modifying the collection, not a standard indexed for-loop.';
//         if (selected === 2) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> The size of an ArrayList <em>can</em> change inside a standard for-loop (since <code>list.size()</code> is evaluated each iteration), which is exactly what causes the shifting problem.';
//         if (selected === 3) feedback.innerHTML = '<strong style="color: #e74c3c;">❌ Incorrect.</strong> <code>ArrayList.remove()</code> does not leave null gaps; it shifts all subsequent elements to the left to fill the gap.';
//     }
// }
// </script>

// %% [markdown]
// ## Scoring Guidelines Part (b)
//
// | Criterion | Decision Rules | Points |
// |-----------|---|---|
// | Declares and initializes an ArrayList of MemberInfo objects | Responses will not earn the point if they initialize the variable with a reference to the instance variable | 1 |
// | Accesses all elements of memberList for potential removal (no bounds errors) | Responses will not earn the point if they: fail to use `get(i)`, fail to attempt to remove an element, skip an element, or throw an exception due to removing | 1 |
// | Calls getGradYear or inGoodStanding | Responses will not earn the point if they ever include parameters in either method call or call either method on an object other than MemberInfo | 1 |
// | Distinguishes any three cases, based on graduation status and standing | Responses will not earn the point if they fail to behave differently in all three cases | 1 |
// | Identifies graduating members | Responses will not earn the point if they confuse `<` and `<=` in the comparison | 1 |
// | Removes appropriate members from memberList and adds appropriate members to the ArrayList to be returned | Responses will not earn the point if they fail to declare an ArrayList to return or fail to distinguish the correct three cases (with exception of confusing `<` and `<=` in comparison) | 1 |
// | **Total for part (b)** | | **6** |
// | **Total for question 3** | | **9** |
