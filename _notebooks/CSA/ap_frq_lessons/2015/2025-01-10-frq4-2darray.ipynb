// %% [raw]
// ---
// layout: post
// courses: { csa: {week: 19} }
// toc: true
// codemirror: true
// title: 2015 FRQ 4
// year: 2015
// frq_number: 4
// unit: [Big Idea Unit Here i.e. Unit 1]
// category: 2D Array Operations
// description: "AP CSA {{ page.year }} FRQ #{{ page.frq_no }} - {{ page.unit }} - {{ page.category }}"
// permalink: /csa/frqs/2015/4
// author: Nora Ahadian
// ---

// %% [markdown]
// ## FRQ Question Part A
//
// A number group represents a group of integers defined in some way. It could be empty, or it could contain one or more integers.
//
// Write an interface named NumberGroup that represents a group of integers. The interface should have a single contains method that determines if a given integer is in the group. For example, if group1 is of type NumberGroup, and it contains only the two numbers -5 and 3, then group1.contains(-5) would return true, and group1.contains(2) would return false.
//
// Write the complete NumberGroup interface. It must have exactly one method.

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto;">
//     <div style="background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #00d4ff;">
//         <h3 style="margin: 0; color: #00d4ff; font-weight: 600; font-size: 18px;">💻 Code Builder: NumberGroup Interface</h3>
//         <p style="margin: 8px 0 0 0; color: rgba(255,255,255,0.8); font-size: 14px;">Click the correct code pieces to build the interface</p>
//     </div>
//     <canvas id="partAGame" width="700" height="450" style="display: block; background: #0f0f1e;"></canvas>
//     <div style="display: flex; justify-content: space-between; align-items: center; padding: 16px; background: #1a1a2e; border-radius: 0 0 12px 12px; box-shadow: 0 4px 6px rgba(0,0,0,0.3);">
//         <span style="color: #aaa; font-size: 14px;">Step: <strong id="stepA" style="color: #00d4ff; font-size: 18px;">1</strong>/4</span>
//         <button onclick="resetGameA()" style="background: #00d4ff; color: #1a1a2e; border: none; padding: 8px 20px; border-radius: 6px; cursor: pointer; font-weight: 600; font-size: 14px;">Restart</button>
//     </div>
// </div>
//
// <script>
// const canvas = document.getElementById('partAGame');
// const ctx = canvas.getContext('2d');
// let currentStep = 0;
// let builtCode = [];
//
// const steps = [
//     {
//         instruction: "Step 1: How do we declare an interface?",
//         options: [
//             { text: "public class NumberGroup", correct: false, explanation: "❌ We need an INTERFACE, not a class!" },
//             { text: "public interface NumberGroup", correct: true, explanation: "✓ Perfect! Interfaces use the 'interface' keyword" },
//             { text: "private interface NumberGroup", correct: false, explanation: "❌ Interfaces must be public!" }
//         ],
//         correctCode: "public interface NumberGroup"
//     },
//     {
//         instruction: "Step 2: How do we start the interface body?",
//         options: [
//             { text: "{ }", correct: false, explanation: "❌ We need curly braces, but let's add the opening one first!" },
//             { text: "{", correct: true, explanation: "✓ Correct! Opening curly brace to start the interface body" },
//             { text: ";", correct: false, explanation: "❌ Semicolons don't start code blocks!" }
//         ],
//         correctCode: "{"
//     },
//     {
//         instruction: "Step 3: What method signature do we need?",
//         options: [
//             { text: "boolean contains(int num);", correct: true, explanation: "✓ Perfect! Returns boolean, takes an int parameter" },
//             { text: "void contains(int num);", correct: false, explanation: "❌ Should return boolean (true/false), not void!" },
//             { text: "public boolean contains(int num) { }", correct: false, explanation: "❌ Interface methods don't have bodies or 'public' keyword!" }
//         ],
//         correctCode: "    boolean contains(int num);"
//     },
//     {
//         instruction: "Step 4: How do we close the interface?",
//         options: [
//             { text: "}", correct: true, explanation: "✓ Correct! Closing curly brace completes the interface" },
//             { text: ";", correct: false, explanation: "❌ We need a closing brace, not a semicolon!" },
//             { text: "end", correct: false, explanation: "❌ Java uses curly braces, not 'end' keyword!" }
//         ],
//         correctCode: "}"
//     }
// ];
//
// function drawGameA() {
//     ctx.clearRect(0, 0, canvas.width, canvas.height);
//
//     // Draw built code so far
//     ctx.fillStyle = "#4ecdc4";
//     ctx.font = "500 12px 'Courier New', monospace";
//     ctx.textAlign = "left";
//     ctx.fillText("Your Code:", 30, 30);
//
//     ctx.strokeStyle = "#00d4ff";
//     ctx.lineWidth = 2;
//     ctx.strokeRect(25, 40, 650, 120);
//
//     ctx.fillStyle = "#ffffff";
//     ctx.font = "600 14px 'Courier New', monospace";
//     let yPos = 65;
//     builtCode.forEach(line => {
//         ctx.fillText(line, 35, yPos);
//         yPos += 25;
//     });
//
//     // Draw blinking cursor if not complete
//     if (currentStep < steps.length) {
//         const cursorX = 35 + ctx.measureText(builtCode[builtCode.length - 1] || "").width;
//         ctx.fillStyle = "#00d4ff";
//         if (Math.floor(Date.now() / 500) % 2 === 0) {
//             ctx.fillRect(cursorX, yPos - 20, 2, 18);
//         }
//     }
//
//     if (currentStep < steps.length) {
//         const step = steps[currentStep];
//
//         // Instruction
//         ctx.fillStyle = "#ff6b9d";
//         ctx.font = "600 15px Inter, sans-serif";
//         ctx.textAlign = "left";
//         ctx.fillText(step.instruction, 30, 195);
//
//         // Option boxes
//         step.options.forEach((option, index) => {
//             const y = 220 + index * 70;
//
//             // Shadow
//             ctx.shadowColor = 'rgba(0, 212, 255, 0.15)';
//             ctx.shadowBlur = 10;
//             ctx.shadowOffsetY = 3;
//
//             // Box
//             ctx.fillStyle = "#1a1a2e";
//             ctx.beginPath();
//             ctx.roundRect(25, y, 650, 55, 8);
//             ctx.fill();
//
//             // Border
//             ctx.strokeStyle = option.correct ? "#4ecdc4" : "#00d4ff";
//             ctx.lineWidth = 2;
//             ctx.beginPath();
//             ctx.roundRect(25, y, 650, 55, 8);
//             ctx.stroke();
//
//             ctx.shadowBlur = 0;
//             ctx.shadowOffsetY = 0;
//
//             // Option text
//             ctx.fillStyle = "#ffffff";
//             ctx.font = "600 14px 'Courier New', monospace";
//             ctx.textAlign = "left";
//             ctx.fillText(option.text, 40, y + 32);
//         });
//     } else {
//         // Success message
//         ctx.fillStyle = "#4ecdc4";
//         ctx.font = "700 20px Inter, sans-serif";
//         ctx.textAlign = "center";
//         ctx.fillText("🎉 Perfect! You've written the interface!", 350, 250);
//
//         ctx.fillStyle = "#aaa";
//         ctx.font = "500 14px Inter, sans-serif";
//         ctx.fillText("This is exactly what the FRQ is asking for:", 350, 290);
//         ctx.fillText("• Public interface named NumberGroup", 350, 320);
//         ctx.fillText("• Single method: boolean contains(int num)", 350, 345);
//         ctx.fillText("• No method body (interfaces only have signatures)", 350, 370);
//     }
//
//     requestAnimationFrame(drawGameA);
// }
//
// canvas.addEventListener('click', (e) => {
//     if (currentStep >= steps.length) return;
//
//     const rect = canvas.getBoundingClientRect();
//     const x = e.clientX - rect.left;
//     const y = e.clientY - rect.top;
//
//     const step = steps[currentStep];
//
//     step.options.forEach((option, index) => {
//         const boxY = 220 + index * 70;
//
//         if (x >= 25 && x <= 675 && y >= boxY && y <= boxY + 55) {
//             if (option.correct) {
//                 alert(option.explanation);
//                 builtCode.push(step.correctCode);
//                 currentStep++;
//                 document.getElementById('stepA').textContent = currentStep + 1;
//
//                 if (currentStep >= steps.length) {
//                     setTimeout(() => {
//                         alert("🎉 Congratulations! You've successfully written the NumberGroup interface!\n\nKey Points:\n✓ Used 'interface' keyword\n✓ Made it public\n✓ Single method with correct signature\n✓ No method body (that's what implementing classes do!)");
//                     }, 500);
//                 }
//             } else {
//                 alert(option.explanation);
//             }
//         }
//     });
// });
//
// function resetGameA() {
//     currentStep = 0;
//     builtCode = [];
//     document.getElementById('stepA').textContent = 1;
// }
//
// // Add rounded rect support
// if (!CanvasRenderingContext2D.prototype.roundRect) {
//     CanvasRenderingContext2D.prototype.roundRect = function(x, y, w, h, r) {
//         this.moveTo(x + r, y);
//         this.lineTo(x + w - r, y);
//         this.quadraticCurveTo(x + w, y, x + w, y + r);
//         this.lineTo(x + w, y + h - r);
//         this.quadraticCurveTo(x + w, y + h, x + w - r, y + h);
//         this.lineTo(x + r, y + h);
//         this.quadraticCurveTo(x, y + h, x, y + h - r);
//         this.lineTo(x, y + r);
//         this.quadraticCurveTo(x, y, x + r, y);
//     };
// }
//
// drawGameA();
// </script>

// %% [markdown]
// **Why use an interface instead of just a range class?**
//
// Flexibility: Range, EvenNumbers, PrimeGroup all behave as NumberGroups
// <br>
// Real-world parallel: Java Collections (List interface → ArrayList, LinkedList)
// <br>
// Testability: Can swap implementations without changing MultipleGroups

// %%
// All valid because of the interface
NumberGroup group1 = new Range(1, 10);
NumberGroup group2 = new OddNumbers();
NumberGroup group3 = new PrimeNumbers();
NumberGroup group4 = new DivisibleBy(7);

// MultipleGroups doesn't care about the implementation
List<NumberGroup> list = Arrays.asList(group1, group2, group3, group4);
MultipleGroups mg = new MultipleGroups(list);

// %% [markdown]
// What would happen if we did this with concrete classes only?

// %%
// CODE_RUNNER: FRQ Part A — NumberGroup Interface

public class Main {

    public interface NumberGroup
    {
        boolean contains(int num);
    }

    // Simple test implementation so we can run it
    static class TestGroup implements NumberGroup
    {
        public boolean contains(int num)
        {
            return num == -5 || num == 3;
        }
    }

    public static void main(String[] args)
    {
        NumberGroup group1 = new TestGroup();

        System.out.println(group1.contains(-5)); // true
        System.out.println(group1.contains(3));  // true
        System.out.println(group1.contains(2));  // false
    }
}

Main.main(null);

// %% [markdown]
// ## Scoring Guidelines Part A (2pts)
//
// +1 interface NumberGroup (point lost if visibility private)
//
// +1 boolean contains(int num); (point lost if visibility not public or extraneous code present)

// %% [markdown]
// ---

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto;">
//     <div style="background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #ff6b9d;">
//         <h3 style="margin: 0; color: #ff6b9d; font-weight: 600; font-size: 18px;">❓ Popcorn Hack: What's Wrong With This Interface?</h3>
//     </div>
//
//     <div style="background: #0f0f1e; padding: 25px; border-radius: 0 0 12px 12px;">
//         <!-- Code Block -->
//         <div style="background: #1a1a2e; border: 2px solid #333; border-radius: 8px; padding: 20px; margin-bottom: 20px;">
//             <pre style="margin: 0; color: #ffffff; font-family: 'Courier New', monospace; font-size: 14px; line-height: 1.6;"><code><span style="color: #c44569;">private</span> <span style="color: #4ecdc4;">interface</span> <span style="color: #00d4ff;">NumberGroup</span> {
//     <span style="color: #c44569;">public</span> <span style="color: #4ecdc4;">boolean</span> <span style="color: #a29bfe;">contains</span>(<span style="color: #4ecdc4;">int</span> num) {
//         <span style="color: #c44569;">return</span> <span style="color: #ff6b9d;">false</span>;
//     }
// }</code></pre>
//         </div>
//
//         <!-- Show Answer Button -->
//         <div style="text-align: center; margin-bottom: 20px;">
//             <button onclick="toggleAnswer()" id="answerBtn" style="background: #ff6b9d; color: #1a1a2e; border: none; padding: 12px 30px; border-radius: 6px; cursor: pointer; font-weight: 600; font-size: 15px; transition: all 0.3s;">
//                 Show Answer
//             </button>
//         </div>
//
//         <!-- Answer Section (Hidden by default) -->
//         <div id="answerSection" style="display: none; background: #1a1a2e; border-left: 4px solid #ff6b9d; border-radius: 8px; padding: 20px; animation: slideDown 0.3s ease;">
//
//             <h4 style="color: #ff6b9d; margin: 0 0 15px 0; font-size: 16px; font-weight: 600;">There are THREE major errors:</h4>
//
//             <!-- Error 1 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #c44569; font-weight: 700; font-size: 18px; margin-bottom: 8px;">1. ❌ private interface</div>
//                 <code style="background: #1a1a2e; padding: 4px 8px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace;">private interface NumberGroup</code>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li>Interfaces must be <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #4ecdc4;">public</code> (or package-private with no modifier)</li>
//                     <li><strong style="color: #fff;">Why:</strong> Interfaces are meant to be implemented by other classes, so they need to be accessible</li>
//                     <li><strong style="color: #4ecdc4;">Fix:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #4ecdc4;">public interface NumberGroup</code></li>
//                 </ul>
//             </div>
//
//             <!-- Error 2 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #c44569; font-weight: 700; font-size: 18px; margin-bottom: 8px;">2. ❌ Method has a body</div>
//                 <pre style="background: #1a1a2e; padding: 10px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace; margin: 8px 0; overflow-x: auto;"><code>public boolean contains(int num) {
//     return false;  <span style="color: #c44569;">// WRONG!</span>
// }</code></pre>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li>Interface methods should <strong style="color: #fff;">only have signatures</strong>, not bodies</li>
//                     <li><strong style="color: #fff;">Why:</strong> Interfaces define the contract (what methods exist), but implementing classes provide the actual code</li>
//                     <li><strong style="color: #4ecdc4;">Fix:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #4ecdc4;">boolean contains(int num);</code> (just the signature with a semicolon)</li>
//                 </ul>
//             </div>
//
//             <!-- Error 3 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #ff9800; font-weight: 700; font-size: 18px; margin-bottom: 8px;">3. ⚠️ Unnecessary public keyword on method</div>
//                 <code style="background: #1a1a2e; padding: 4px 8px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace;">public boolean contains(int num)</code>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li>Interface methods are <strong style="color: #fff;">implicitly public</strong>, so the <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">public</code> keyword is redundant</li>
//                     <li><strong style="color: #fff;">Best practice:</strong> Just write <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #4ecdc4;">boolean contains(int num);</code></li>
//                     <li><strong style="color: #ff9800;">Note:</strong> The AP exam scoring guidelines penalize this</li>
//                 </ul>
//             </div>
//
//             <!-- Correct Version -->
//             <div style="padding: 15px; background: #1a3a1a; border: 2px solid #4ecdc4; border-radius: 6px;">
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 16px; margin-bottom: 10px;">✅ Correct Version:</div>
//                 <pre style="background: #0f0f1e; padding: 15px; border-radius: 4px; margin: 0;"><code style="color: #ffffff; font-family: 'Courier New', monospace; font-size: 14px;"><span style="color: #4ecdc4;">public</span> <span style="color: #4ecdc4;">interface</span> <span style="color: #00d4ff;">NumberGroup</span> {
//     <span style="color: #4ecdc4;">boolean</span> <span style="color: #a29bfe;">contains</span>(<span style="color: #4ecdc4;">int</span> num);
// }</code></pre>
//             </div>
//
//             <!-- Key Takeaways -->
//             <div style="margin-top: 20px; padding: 15px; background: #16213e; border-radius: 6px;">
//                 <div style="color: #00d4ff; font-weight: 700; font-size: 15px; margin-bottom: 10px;">📝 Key Takeaways:</div>
//                 <ul style="color: #aaa; margin: 0; padding-left: 20px; line-height: 1.8;">
//                     <li>✓ <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #4ecdc4;">public interface</code> (not private)</li>
//                     <li>✓ Method signature only (no body <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">{}</code>)</li>
//                     <li>✓ No <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">public</code> modifier on the method (it's implicit)</li>
//                 </ul>
//             </div>
//
//         </div>
//     </div>
// </div>
//
// <style>
// @keyframes slideDown {
//     from {
//         opacity: 0;
//         transform: translateY(-10px);
//     }
//     to {
//         opacity: 1;
//         transform: translateY(0);
//     }
// }
//
// #answerBtn:hover {
//     background: #ff8fb8 !important;
//     transform: scale(1.05);
// }
// </style>
//
// <script>
// function toggleAnswer() {
//     const answerSection = document.getElementById('answerSection');
//     const btn = document.getElementById('answerBtn');
//
//     if (answerSection.style.display === 'none') {
//         answerSection.style.display = 'block';
//         btn.textContent = 'Hide Answer';
//         btn.style.background = '#4ecdc4';
//     } else {
//         answerSection.style.display = 'none';
//         btn.textContent = 'Show Answer';
//         btn.style.background = '#ff6b9d';
//     }
// }
// </script>

// %% [markdown]
// ## FRQ Question Part B
//
// A range represents a number group that contains all (and only) the integers between a minimum value and a maximum value, inclusive.
//
// Write the Range class, which is a NumberGroup. The Range class represents the group of int values that range from a given minimum value up through a given maximum value, inclusive. For example,the declaration
//
// `NumberGroup range1 = new Range(-3, 2);`
//
// Numbergroup: Interface type - defines what methods are available
// <br>
// new Range: Concrete class - defines how methods work represents the group of integer values -3, -2, -1, 0, 1, 2.
//
// Write the complete Range class. Include all necessary instance variables and methods as well as a constructor that takes two `int` parameters. The first parameter represents the minimum value, and the second parameter represents the maximum value of the range. You may assume that the minimum is less than or equal to the maximum.

// %%
// CODE_RUNNER: FRQ Part B — Range Class

public class Main {

    interface NumberGroup
    {
        boolean contains(int num);
    }

    public class Range implements NumberGroup
    {
        private int min;
        private int max;

        public Range(int min, int max)
        {
            this.min = min;
            this.max = max;
        }

        public boolean contains(int num)
        {
            return num >= min && num <= max;
        }
    }

    public static void main(String[] args)
    {
        NumberGroup range1 = new Main().new Range(-3, 2);

        System.out.println(range1.contains(-3)); // true
        System.out.println(range1.contains(0));  // true
        System.out.println(range1.contains(2));  // true
        System.out.println(range1.contains(3));  // false
    }
}

Main.main(null);

// %% [markdown]
// ## Scoring Guidelines Part B (5pts)
//
// +1 class Range implements NumberGroup (point lost if visibility private)
//
// +1 Declares appropriate private instance variable(s)
//
// +1 Uses correct constructor header
//
// +1 Initializes instance variables within constructor using parameters
// (point lost if bounds errors occur in container use)
//
// +1 Computes and returns correct value from contains
// (point lost for incorrect method header)

// %% [markdown]
// ---

// %% [markdown]
// ## FRQ Question Part C
//
// The MultipleGroups class (not shown) represents a collection of NumberGroup objects and is a NumberGroup. The MultipleGroups class stores the number groups in the instance variable groupList (shown below), which is initialized in the constructor.
//
// `private List<NumberGroup> groupList;`
//
// Write the MultipleGroups method contains. The method takes an integer and returns true if and only if the integer is contained in one or more of the number groups in groupList.
//
// For example, suppose multiple1 has been declared as an instance of MultipleGroups and consists of the three ranges created by the calls new Range(5, 8), new Range(10, 12), and new Range(1, 6). The following table shows the results of several calls to contains.
//
// | Call                 | Result |
// |----------------------------|--------|
// | multiple1.contains(2)    | true   |
// | multiple1.contains(9)    | false  |
// | multiple1.contains(6)    | true   |
//
// Enhanced For-loop
//
// `for (NumberGroup group : groupList) {
//     if (group.contains(num)) { ... }
// }`
// x
// Loop variable type matches interface and works with any class that implements NumberGroup

// %%
// CODE_RUNNER: FRQ Part C — MultipleGroups

import java.util.List;
import java.util.ArrayList;

public class Main {

    interface NumberGroup
    {
        boolean contains(int num);
    }

    static class Range implements NumberGroup
    {
        private int min;
        private int max;

        public Range(int min, int max)
        {
            this.min = min;
            this.max = max;
        }

        public boolean contains(int num)
        {
            return num >= min && num <= max;
        }
    }

    class MultipleGroups implements NumberGroup
    {
        private List<NumberGroup> groupList;

        public MultipleGroups(List<NumberGroup> groups)
        {
            groupList = groups;
        }

        public boolean contains(int num)
        {
            for (NumberGroup group : groupList)
            {
                if (group.contains(num))
                {
                    return true;
                }
            }
            return false;
        }
    }

    public static void main(String[] args)
    {
        NumberGroup g1 = new Range(5, 8);
        NumberGroup g2 = new Range(10, 12);
        NumberGroup g3 = new Range(1, 6);

        List<NumberGroup> list = new ArrayList<>();
        list.add(g1);
        list.add(g2);
        list.add(g3);

        MultipleGroups multiple1 = new Main().new MultipleGroups(list);

        System.out.println(multiple1.contains(2)); // true
        System.out.println(multiple1.contains(9)); // false
        System.out.println(multiple1.contains(6)); // true
    }
}

Main.main(null);

// %% [markdown]
// ## Scoring Guidelines Part C (2pts)
//
// +1 Calls contains on elements of groupList in context of loop (no bounds errors)
//
// +1 Computes and returns correct value

// %% [markdown]
// <div style="font-family: 'Inter', -apple-system, BlinkMacSystemFont, 'Segoe UI', sans-serif; max-width: 700px; margin: 0 auto;">
//     <div style="background: linear-gradient(135deg, #1a1a2e 0%, #16213e 100%); padding: 20px; border-radius: 12px 12px 0 0; border-bottom: 2px solid #4ecdc4;">
//         <h3 style="margin: 0; color: #4ecdc4; font-weight: 600; font-size: 18px;">❓ Popcorn Hack: Test Your Understanding</h3>
//     </div>
//
//     <div style="background: #0f0f1e; padding: 25px; border-radius: 0 0 12px 12px;">
//         <!-- Question -->
//         <div style="color: #fff; margin-bottom: 20px; line-height: 1.6;">
//             <p style="margin: 0 0 15px 0; font-size: 15px;">Given these Range objects, what should these method calls return?</p>
//         </div>
//
//         <!-- Code Block -->
//         <div style="background: #1a1a2e; border: 2px solid #333; border-radius: 8px; padding: 20px; margin-bottom: 20px;">
//             <pre style="margin: 0; color: #ffffff; font-family: 'Courier New', monospace; font-size: 14px; line-height: 1.6;"><code><span style="color: #4ecdc4;">Range</span> r1 = <span style="color: #c44569;">new</span> <span style="color: #4ecdc4;">Range</span>(<span style="color: #ff6b9d;">5</span>, <span style="color: #ff6b9d;">5</span>);
// r1.<span style="color: #a29bfe;">contains</span>(<span style="color: #ff6b9d;">5</span>);  <span style="color: #888;">// ???</span>
//
// <span style="color: #4ecdc4;">Range</span> r2 = <span style="color: #c44569;">new</span> <span style="color: #4ecdc4;">Range</span>(<span style="color: #ff6b9d;">-10</span>, <span style="color: #ff6b9d;">-5</span>);
// r2.<span style="color: #a29bfe;">contains</span>(<span style="color: #ff6b9d;">-7</span>);  <span style="color: #888;">// ???</span>
//
// <span style="color: #4ecdc4;">Range</span> r3 = <span style="color: #c44569;">new</span> <span style="color: #4ecdc4;">Range</span>(<span style="color: #ff6b9d;">0</span>, <span style="color: #ff6b9d;">100</span>);
// r3.<span style="color: #a29bfe;">contains</span>(<span style="color: #ff6b9d;">0</span>);   <span style="color: #888;">// ???</span>
// r3.<span style="color: #a29bfe;">contains</span>(<span style="color: #ff6b9d;">100</span>); <span style="color: #888;">// ???</span></code></pre>
//         </div>
//
//         <!-- Show Answer Button -->
//         <div style="text-align: center; margin-bottom: 20px;">
//             <button onclick="toggleAnswerBoundary()" id="answerBtnBoundary" style="background: #4ecdc4; color: #1a1a2e; border: none; padding: 12px 30px; border-radius: 6px; cursor: pointer; font-weight: 600; font-size: 15px; transition: all 0.3s;">
//                 Show Answer
//             </button>
//         </div>
//
//         <!-- Answer Section (Hidden by default) -->
//         <div id="answerSectionBoundary" style="display: none; background: #1a1a2e; border-left: 4px solid #4ecdc4; border-radius: 8px; padding: 20px; animation: slideDown 0.3s ease;">
//
//             <h4 style="color: #4ecdc4; margin: 0 0 15px 0; font-size: 16px; font-weight: 600;">All return TRUE! Here's why:</h4>
//
//             <!-- Answer 1 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 16px; margin-bottom: 8px;">1. ✓ r1.contains(5) → true</div>
//                 <code style="background: #1a1a2e; padding: 4px 8px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace;">Range(5, 5)</code>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li><strong style="color: #fff;">Why:</strong> A range can have the same min and max!</li>
//                     <li><strong style="color: #fff;">Logic:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">5 >= 5 && 5 <= 5</code> is true</li>
//                     <li><strong style="color: #4ecdc4;">Result:</strong> This range contains only the number 5</li>
//                 </ul>
//             </div>
//
//             <!-- Answer 2 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 16px; margin-bottom: 8px;">2. ✓ r2.contains(-7) → true</div>
//                 <code style="background: #1a1a2e; padding: 4px 8px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace;">Range(-10, -5)</code>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li><strong style="color: #fff;">Why:</strong> Ranges work with negative numbers too!</li>
//                     <li><strong style="color: #fff;">Logic:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">-7 >= -10 && -7 <= -5</code> is true</li>
//                     <li><strong style="color: #4ecdc4;">Result:</strong> -7 is between -10 and -5 (inclusive)</li>
//                 </ul>
//             </div>
//
//             <!-- Answer 3 & 4 -->
//             <div style="margin-bottom: 20px; padding: 15px; background: #0f0f1e; border-radius: 6px;">
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 16px; margin-bottom: 8px;">3. ✓ r3.contains(0) → true</div>
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 16px; margin-bottom: 8px;">4. ✓ r3.contains(100) → true</div>
//                 <code style="background: #1a1a2e; padding: 4px 8px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace;">Range(0, 100)</code>
//                 <ul style="color: #aaa; margin: 10px 0 0 0; padding-left: 20px; line-height: 1.8;">
//                     <li><strong style="color: #fff;">Why:</strong> The boundaries are <strong>INCLUSIVE</strong> (uses >= and <=)</li>
//                     <li><strong style="color: #fff;">For 0:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">0 >= 0 && 0 <= 100</code> is true</li>
//                     <li><strong style="color: #fff;">For 100:</strong> <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">100 >= 0 && 100 <= 100</code> is true</li>
//                     <li><strong style="color: #4ecdc4;">Result:</strong> Both minimum and maximum values are included in the range</li>
//                 </ul>
//             </div>
//
//             <!-- The Key Point -->
//             <div style="padding: 15px; background: #2d1b3d; border-left: 4px solid #a29bfe; border-radius: 6px; margin-bottom: 20px;">
//                 <div style="color: #a29bfe; font-weight: 700; font-size: 15px; margin-bottom: 10px;">🔑 The Key Point: INCLUSIVE Boundaries</div>
//                 <div style="color: #aaa; line-height: 1.8;">
//                     <p style="margin: 0 0 10px 0;">The contains method uses <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">>=</code> and <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;"><=</code> (not <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">></code> and <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;"><</code>)</p>
//                     <p style="margin: 0;">This means the range <strong style="color: #fff;">includes</strong> both the minimum and maximum values.</p>
//                 </div>
//             </div>
//
//             <!-- Code Reference -->
//             <div style="padding: 15px; background: #1a3a1a; border: 2px solid #4ecdc4; border-radius: 6px;">
//                 <div style="color: #4ecdc4; font-weight: 700; font-size: 15px; margin-bottom: 10px;">📝 Reference: The contains() method</div>
//                 <pre style="background: #0f0f1e; padding: 15px; border-radius: 4px; margin: 0;"><code style="color: #ffffff; font-family: 'Courier New', monospace; font-size: 14px;"><span style="color: #c44569;">public</span> <span style="color: #4ecdc4;">boolean</span> <span style="color: #a29bfe;">contains</span>(<span style="color: #4ecdc4;">int</span> num) {
//     <span style="color: #c44569;">return</span> num >= min && num <= max;
//     <span style="color: #888;">// ^^           ^^</span>
//     <span style="color: #888;">// Equal signs make it INCLUSIVE!</span>
// }</code></pre>
//             </div>
//
//             <!-- Common Mistake -->
//             <div style="margin-top: 20px; padding: 15px; background: #3a1a1a; border-left: 4px solid #c44569; border-radius: 6px;">
//                 <div style="color: #c44569; font-weight: 700; font-size: 15px; margin-bottom: 10px;">⚠️ Common Mistake to Avoid:</div>
//                 <div style="color: #aaa; line-height: 1.8; font-size: 14px;">
//                     <p style="margin: 0 0 10px 0;">If you used <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #c44569;">></code> and <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #c44569;"><</code> instead:</p>
//                     <code style="background: #1a1a2e; padding: 8px 12px; border-radius: 4px; color: #ffffff; font-family: 'Courier New', monospace; display: block;">return num > min && num < max;  // WRONG!</code>
//                     <p style="margin: 10px 0 0 0;">Then <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">Range(0, 100).contains(0)</code> and <code style="background: #1a1a2e; padding: 2px 6px; border-radius: 3px; color: #fff;">.contains(100)</code> would both return <strong style="color: #c44569;">false</strong>—you'd lose a point!</p>
//                 </div>
//             </div>
//
//         </div>
//     </div>
// </div>
//
// <style>
// @keyframes slideDown {
//     from {
//         opacity: 0;
//         transform: translateY(-10px);
//     }
//     to {
//         opacity: 1;
//         transform: translateY(0);
//     }
// }
//
// #answerBtnBoundary:hover {
//     background: #6ee7dd !important;
//     transform: scale(1.05);
// }
// </style>
//
// <script>
// function toggleAnswerBoundary() {
//     const answerSection = document.getElementById('answerSectionBoundary');
//     const btn = document.getElementById('answerBtnBoundary');
//
//     if (answerSection.style.display === 'none') {
//         answerSection.style.display = 'block';
//         btn.textContent = 'Hide Answer';
//         btn.style.background = '#ff6b9d';
//     } else {
//         answerSection.style.display = 'none';
//         btn.textContent = 'Show Answer';
//         btn.style.background = '#4ecdc4';
//     }
// }
// </script>

// %% [markdown]
// ## Question-Specific Penalties
//
// -1 (s) Inappropriate use of static
//
// **Other common mistakes**
// Part B: Forgetting private on instance variables (-1)
// Part B: Using > and < instead of >= and <= (-1)
// Part A: Adding method body to interface (-1)
// Part C: Messing up loop logic (-1 or -2)

// %% [markdown]
// Alternate Solutions

// %%
// Solution 1
public class Range implements NumberGroup {
    private int min, max;
    
    public Range(int minimum, int maximum) {
        min = minimum;
        max = maximum;
    }
    
    public boolean contains(int num) {
        return num >= min && num <= max;
    }
}

// Solution 2
public class Range implements NumberGroup {
    private int minVal;
    private int maxVal;
    
    public Range(int min, int max) {
        this.minVal = min;
        this.maxVal = max;
    }
    
    public boolean contains(int value) {
        if (value >= minVal && value <= maxVal)
            return true;
        return false;
    }
}

// Solution 3
public class Range implements NumberGroup {
    private int low, high;
    
    public Range(int a, int b) {
        low = a;
        high = b;
    }
    
    public boolean contains(int num) {
        return (num >= low && num <= high);
    }
}
